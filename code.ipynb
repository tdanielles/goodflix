# %%
import pandas as pd
import re

movies = pd.read_csv("movies.csv")

# %%
def clean_title(title):
    return re.sub("[^a-zA-Z0-9 ]", "", title)

# %%
movies["clean_title"] = movies["title"].apply(clean_title).str[:-5]

# %%
movies
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
#                                             genres  \
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...                                            ...
# 62418                                        Drama
# 62419                                  Documentary
# 62420                                 Comedy|Drama
# 62421                           (no genres listed)
# 62422                       Action|Adventure|Drama
#
#                        clean_title
# 0                        Toy Story
# 1                          Jumanji
# 2                 Grumpier Old Men
# 3                Waiting to Exhale
# 4      Father of the Bride Part II
# ...                            ...
# 62418                           We
# 62419           Window of the Soul
# 62420                    Bad Poems
# 62421                 A Girl Thing
# 62422       Women of Devils Island
#
# [62423 rows x 4 columns]

# %%
ratings = pd.read_csv("ratings.csv")

# %%
ratings
# Out:
#           userId  movieId  rating   timestamp
# 0              1      296     5.0  1147880044
# 1              1      306     3.5  1147868817
# 2              1      307     5.0  1147868828
# 3              1      665     5.0  1147878820
# 4              1      899     3.5  1147868510
# ...          ...      ...     ...         ...
# 22327994  145199    87232     4.0  1494733204
# 22327995  145199    88125     5.0  1494733106
# 22327996  145199    91630     2.0  1494734866
# 22327997  145199    95167     4.5  1494735246
# 22327998  145199    99114     4.0    14947332
#
# [22327999 rows x 4 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(ngram_range=(1,2))

tfidf = vectorizer.fit_transform(movies["clean_title"])

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Find id given title
def find(movie_title):
    movie_title = clean_title(movie_title)
    query_vec = vectorizer.transform([movie_title])
    
    similarity = cosine_similarity(query_vec, tfidf).flatten()
    
    index = np.argpartition(similarity, -5)[-5:]
    result = movies.iloc[index][::-1][:1]
    
    return result.movieId.item()

# %%
find("Batman")
# Out:
# 153

# %%
# Recommendation algo
def recommend(movie_title):
    movie_id = find(movie_title)
    
    # finding recommendations from users similar to us
    similar_users = ratings[(ratings["movieId"] == movie_id) & (ratings["rating"] > 4)]["userId"].unique()
    similar_user_recs = ratings[(ratings["userId"].isin(similar_users)) & (ratings["rating"] > 4)]["movieId"]
    
    # adjusting so we only have recommendations where over 10% of users recommended that movie
    similar_user_recs = similar_user_recs.value_counts() / len(similar_users)
    similar_user_recs = similar_user_recs[similar_user_recs > .10]
    
    # finding how common the recommendation is among all users
    all_users = ratings[(ratings["movieId"].isin(similar_user_recs.index)) & (ratings["rating"] > 4)]
    all_users_recs = all_users["movieId"].value_counts() / len(all_users["userId"].unique())
    
    # creating recommendation score
    rec_percentages = pd.concat([similar_user_recs, all_users_recs], axis=1)
    rec_percentages.columns = ["similar", "all"]
    
    rec_percentages["score"] = rec_percentages["similar"] / rec_percentages["all"]
    
    rec_percentages = rec_percentages.sort_values("score", ascending=False)
    return rec_percentages.head(10).merge(movies, left_index=True, right_on="movieId")

# %%
recommend("Harry Potter")
# Out:
#         similar       all      score  movieId  \
# 13512  1.000000  0.032988  30.313919    69844
# 15538  0.731713  0.034705  21.083634    81834
# 11700  0.638615  0.030295  21.079716    54001
# 16718  0.668654  0.036105  18.519880    88125
# 10408  0.650080  0.038510  16.880762    40815
# 29962  0.123137  0.008404  14.652182   135143
# 5704   0.528778  0.037398  14.139138     5816
# 7742   0.685393  0.049395  13.875697     8368
# 23024  0.120844  0.008911  13.561490   116823
# 23594  0.127494  0.009773  13.045309   118696
#
#                                                    title  \
# 13512      Harry Potter and the Half-Blood Prince (2009)
# 15538  Harry Potter and the Deathly Hallows: Part 1 (...
# 11700   Harry Potter and the Order of the Phoenix (2007)
# 16718  Harry Potter and the Deathly Hallows: Part 2 (...
# 10408         Harry Potter and the Goblet of Fire (2005)
# 29962     Fantastic Beasts and Where to Find Them (2016)
# 5704      Harry Potter and the Chamber of Secrets (2002)
# 7742     Harry Potter and the Prisoner of Azkaban (2004)
# 23024       The Hunger Games: Mockingjay - Part 1 (2014)
# 23594   The Hobbit: The Battle of the Five Armies (2014)
#
#                                             genres  \
# 13512       Adventure|Fantasy|Mystery|Romance|IMAX
# 15538                Action|Adventure|Fantasy|IMAX
# 11700                 Adventure|Drama|Fantasy|IMAX
# 16718  Action|Adventure|Drama|Fantasy|Mystery|IMAX
# 10408              Adventure|Fantasy|Thriller|IMAX
# 29962                                      Fantasy
# 5704                             Adventure|Fantasy
# 7742                        Adventure|Fantasy|IMAX
# 23024                    Adventure|Sci-Fi|Thriller
# 23594                            Adventure|Fantasy
#
#                                        clean_title
# 13512        Harry Potter and the HalfBlood Prince
# 15538  Harry Potter and the Deathly Hallows Part 1
# 11700    Harry Potter and the Order of the Phoenix
# 16718  Harry Potter and the Deathly Hallows Part 2
# 10408          Harry Potter and the Goblet of Fire
# 29962      Fantastic Beasts and Where to Find Them
# 5704       Harry Potter and the Chamber of Secrets
# 7742      Harry Potter and the Prisoner of Azkaban
# 23024          The Hunger Games Mockingjay  Part 1
# 23594     The Hobbit The Battle of the Five Armies

# %%
import pickle

pickle.dump(movies.to_dict(), open("movies_dict.pkl", "wb"))

# %%
pickle.dump(ratings, open("ratings.pkl", "wb"))

# %%
recommend("Sabrina")
# Out:
# Empty DataFrame
# Columns: [similar, all, score, movieId, title, genres, clean_title]
# Index: []

# %%
recommend("Dracula")
# Out:
#        similar       all     score  movieId  \
# 12951     0.25  0.000007  34834.75    65352
# 3671      0.25  0.000007  34834.75     3772
# 13430     0.25  0.000007  34834.75    69419
# 12962     0.25  0.000007  34834.75    65518
# 5780      0.25  0.000007  34834.75     5892
# 9676      0.25  0.000007  34834.75    32088
# 12646     0.25  0.000007  34834.75    61638
# 4939      0.25  0.000007  34834.75     5045
# 6592      0.25  0.000007  34834.75     6715
# 2361      0.25  0.000007  34834.75     2452
#
#                                                    title  \
# 12951                    Have Rocket, Will Travel (1959)
# 3671   Hatchet for the Honeymoon (Rosso segno della f...
# 13430                          Crawling Hand, The (1963)
# 12962                          Dungeonmaster, The (1985)
# 5780          Island at the Top of the World, The (1974)
# 9676                                          DNA (1997)
# 12646                             Flu Bird Horror (2008)
# 4939                                     Galaxina (1980)
# 6592                        Children of the Night (1991)
# 2361                    Gate II: Trespassers, The (1990)
#
#                           genres  \
# 12951              Comedy|Sci-Fi
# 3671     Fantasy|Horror|Thriller
# 13430              Horror|Sci-Fi
# 12962      Fantasy|Horror|Sci-Fi
# 5780   Action|Adventure|Children
# 9676               Action|Sci-Fi
# 12646            Horror|Thriller
# 4939               Comedy|Sci-Fi
# 6592                      Horror
# 2361                      Horror
#
#                                              clean_title
# 12951                            Have Rocket Will Travel
# 3671   Hatchet for the Honeymoon Rosso segno della fo...
# 13430                                  Crawling Hand The
# 12962                                  Dungeonmaster The
# 5780                  Island at the Top of the World The
# 9676                                                 DNA
# 12646                                    Flu Bird Horror
# 4939                                            Galaxina
# 6592                               Children of the Night
# 2361                             Gate II Trespassers The

# %%
recommend("Sudden Death")
# Out:
# Empty DataFrame
# Columns: [similar, all, score, movieId, title, genres, clean_title]
# Index: []
